# %%
import pandas as pd

# %%
df = pd.read_csv('products.csv')
df
# Out:
#      Index                                    Name  \
# 0        1                 Thermostat Drone Heater
# 1        2   Ultra Speaker Iron Grill Advanced One
# 2        3                 Watch Headphones Kettle
# 3        4   Portable Toaster Clock Monitor Silent
# 4        5                        Pro Toaster Oven
# ..     ...                                     ...
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Brand']
# Out:
# 0                       Bradford-Yu
# 1                     Douglas Group
# 2                     Landry-Austin
# 3           Odom, Norton and Foster
# 4      Fowler, Mendoza and Mcdaniel
#                    ...
# 995                   Huffman Group
# 996                  Woodward Group
# 997                  Ramos-Cardenas
# 998                   Hooper-Bender
# 999                      Campos Inc
# Name: Brand, Length: 1000, dtype: object

# %%
type(df['Brand'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Create a dataframe from a Dictionary

# %%
tempDict = {
    'Name': ['Rushi', 'Shubham', 'Soham', 'Vaishnav'],
    'Designation': ['S/W Engineer', 'C.A', 'Police', 'Collector'],
    'Salary' : [2000000, 3000000, 4000000, 5000000]
}

# %%
dictDf = pd.DataFrame.from_dict(tempDict)

# %%
dictDf
# Out:
#        Name   Designation   Salary
# 0     Rushi  S/W Engineer  2000000
# 1   Shubham           C.A  3000000
# 2     Soham        Police  4000000
# 3  Vaishnav     Collector  5000000

# %%
df.columns
# Out:
# Index(['Index', 'Name', 'Description', 'Brand', 'Category', 'Price',
#        'Currency', 'Stock', 'EAN', 'Color', 'Size', 'Availability',
#        'Internal ID'],
#       dtype='object')

# %%
dictDf.columns
# Out:
# Index(['Name', 'Designation', 'Salary'], dtype='object')

# %%
dictDf.dtypes
# Out:
# Name           object
# Designation    object
# Salary          int64
# dtype: object

# %%
dictDf[['Name', 'Salary']]
# Out:
#        Name   Salary
# 0     Rushi  2000000
# 1   Shubham  3000000
# 2     Soham  4000000
# 3  Vaishnav  5000000

# %%
df.columns
# Out:
# Index(['Index', 'Name', 'Description', 'Brand', 'Category', 'Price',
#        'Currency', 'Stock', 'EAN', 'Color', 'Size', 'Availability',
#        'Internal ID'],
#       dtype='object')

# %%
df.Brand.unique()
# Out:
# array(['Bradford-Yu', 'Douglas Group', 'Landry-Austin',
#        'Odom, Norton and Foster', 'Fowler, Mendoza and Mcdaniel',
#        'Burton-Gould', 'Soto, Raymond and Doyle',
#        'Padilla, Dunn and Pruitt', 'Hughes and Sons', 'Mcbride-Wyatt',
#        'Wilkins, Horne and Farrell', 'Miranda, Lucero and Blevins',
#        'Marshall Group', 'Tanner LLC', 'Mathews and Sons',
#        'Stephenson PLC', 'Leonard LLC', 'Montes, Hickman and Stout',
#        'Matthews Ltd', 'Contreras-Bonilla', 'Greene-Ayers', 'Hanna Group',
#        'Quinn-Fields', 'Livingston-Steele',
#        'Pearson, Hubbard and Woodward', 'Zavala, Pugh and Wiley',
#        'Mcfarland-Buck', 'Kirby and Sons', 'Owen, Caldwell and Salazar',
#        'Montoya Group', 'Franklin, Liu and Evans', 'Harrison Ltd',
#        'Kennedy-Weiss', 'Joyce, Mcdonald and Maldonado',
#        'Mills, Mendez and Waller', 'Maldonado PLC',
#        'Payne, Joseph and Ponce', 'Roman and Sons', 'Duarte Ltd',
# ...

# %%
df.Name.unique()
# Out:
# array(['Thermostat Drone Heater', 'Ultra Speaker Iron Grill Advanced One',
#        'Watch Headphones Kettle', 'Portable Toaster Clock Monitor Silent',
#        'Pro Toaster Oven', 'Mini Speakerphone Mixer',
#        'Eco Cooler Printer Speaker Prime Prime',
#        'Webcam Trimmer Projector',
#        'Silent Headphones Stove Wireless Air Clean',
#        'Wireless Charger Air Premium Ultra',
#        'Portable Fan Monitor Toaster Pro Smart Air', 'Mini Iron Drone',
#        'Smart Grill Tablet Fridge Sense', 'Portable Grill Air Edge',
#        'Premium Brush Scale Grill Plus Plus', 'Vacuum Router Toaster',
#        'Digital Clock Lock Eco Premium Portable',
#        'Fast Watch Microphone Microphone', 'Clean Dock Mixer Router',
#        'Cooker Brush', 'Premium Cooler Premium Sense',
#        'Digital Powerbank Rechargeable Wireless',
#        'Digital Drone Advanced', 'Automatic Thermostat Drone Heater',
#        'Clean Webcam Powerbank Portable Compact', 'Headphones',
# ...

# %%
df.head()
# Out:
#    Index                                   Name  \
# 0      1                Thermostat Drone Heater
# 1      2  Ultra Speaker Iron Grill Advanced One
# 2      3                Watch Headphones Kettle
# 3      4  Portable Toaster Clock Monitor Silent
# 4      5                       Pro Toaster Oven
#
#                                        Description  \
# 0           Consumer approach woman us those star.
# 1  Point suggest easy money operation could white.
# 2                         Reach husband education.
# 3            Always choose school poor table main.
# 4          Worry put discuss easy back too career.
#
#                           Brand                Category  Price Currency  \
# 0                   Bradford-Yu      Kitchen Appliances     74      USD
# 1                 Douglas Group       Fitness Equipment    510      USD
# 2                 Landry-Austin  Beauty & Personal Care    254      USD
# ...

# %%
df['Availability']
# Out:
# 0          backorder
# 1          backorder
# 2          pre_order
# 3           in_stock
# 4           in_stock
#            ...
# 995    limited_stock
# 996     out_of_stock
# 997        pre_order
# 998         in_stock
# 999    limited_stock
# Name: Availability, Length: 1000, dtype: object

# %%
df[df['Availability'] == 'in_stock']
# Out:
#      Index                                      Name  \
# 3        4     Portable Toaster Clock Monitor Silent
# 4        5                          Pro Toaster Oven
# 9       10        Wireless Charger Air Premium Ultra
# 11      12                           Mini Iron Drone
# 16      17   Digital Clock Lock Eco Premium Portable
# ..     ...                                       ...
# 978    979           Compact Fan Iron Cooker Go Mini
# 989    990         Advanced Heater Ultra Wireless Go
# 993    994  Portable Clock Drone Charger Clean Ultra
# 994    995      Compact Scale Headphones Sense Prime
# 998    999    Portable Cooker Brush 360 Digital Mini
#
#                                      Description  \
# 3          Always choose school poor table main.
# 4        Worry put discuss easy back too career.
# 9                          Public security home.
# 11        Small meet inside career walk company.
# 16                            On ago smile stop.
# ...

# %%
df[(df['Availability'] == 'in_stock') & (df['Size'] == 'XL')]
# Out:
#      Index                                            Name  \
# 3        4           Portable Toaster Clock Monitor Silent
# 4        5                                Pro Toaster Oven
# 16      17         Digital Clock Lock Eco Premium Portable
# 163    164  Smart Drone Thermostat Headphones Touch Go Eco
# 425    426                                 Blender Blender
# 957    958                Smart Scooter Bicycle Oven Smart
#
#                                       Description  \
# 3           Always choose school poor table main.
# 4         Worry put discuss easy back too career.
# 16                             On ago smile stop.
# 163              Relate future see last industry.
# 425                 Loss manage participant into.
# 957  Know worker street how enough chair program.
#
#                             Brand         Category  Price Currency  Stock  \
# 3         Odom, Norton and Foster           Makeup     69      USD    119
# ...

# %%
df.iloc[424]
# Out:
# Index                                               425
# Name                                             Heater
# Description     During anyone possible difference fund.
# Brand                                       Trevino Inc
# Category                         Beauty & Personal Care
# Price                                               601
# Currency                                            USD
# Stock                                               320
# EAN                                       3573654296367
# Color                                       ForestGreen
# Size                                           50x70 cm
# Availability                                   in_stock
# Internal ID                                          40
# Name: 424, dtype: object

# %%
df.iloc[424, 1]
# Out:
# 'Heater'

# %%
df.iloc[424, -2]
# Out:
# 'in_stock'

# %%
df.iloc[9:20]
# Out:
#     Index                                        Name  \
# 9      10          Wireless Charger Air Premium Ultra
# 10     11  Portable Fan Monitor Toaster Pro Smart Air
# 11     12                             Mini Iron Drone
# 12     13             Smart Grill Tablet Fridge Sense
# 13     14                     Portable Grill Air Edge
# 14     15         Premium Brush Scale Grill Plus Plus
# 15     16                       Vacuum Router Toaster
# 16     17     Digital Clock Lock Eco Premium Portable
# 17     18            Fast Watch Microphone Microphone
# 18     19                     Clean Dock Mixer Router
# 19     20                                Cooker Brush
#
#                                          Description  \
# 9                              Public security home.
# 10       Number create north effect deep third hard.
# 11            Small meet inside career walk company.
# 12                    Eat describe discussion today.
# ...

# %%
state = df.copy()
state.set_index('Name', inplace= True)

# %%
state.head()
# Out:
#                                        Index  \
# Name
# Thermostat Drone Heater                    1
# Ultra Speaker Iron Grill Advanced One      2
# Watch Headphones Kettle                    3
# Portable Toaster Clock Monitor Silent      4
# Pro Toaster Oven                           5
#
#                                                                            Description  \
# Name
# Thermostat Drone Heater                         Consumer approach woman us those star.
# Ultra Speaker Iron Grill Advanced One  Point suggest easy money operation could white.
# Watch Headphones Kettle                                       Reach husband education.
# Portable Toaster Clock Monitor Silent            Always choose school poor table main.
# Pro Toaster Oven                               Worry put discuss easy back too career.
#
#                                                               Brand  \
# Name
# Thermostat Drone Heater                                 Bradford-Yu
# ...

# %%
state.loc['Oven']
# Out:
# Index                                             848
# Description     There week myself fall bar image not.
# Brand                                      Vance-Howe
# Category                                    Furniture
# Price                                             578
# Currency                                          USD
# Stock                                             931
# EAN                                     3868555265018
# Color                                          Bisque
# Size                                                M
# Availability                                 in_stock
# Internal ID                                        61
# Name: Oven, dtype: object

# %%
state.reset_index()
# Out:
#                                        Name  Index  \
# 0                   Thermostat Drone Heater      1
# 1     Ultra Speaker Iron Grill Advanced One      2
# 2                   Watch Headphones Kettle      3
# 3     Portable Toaster Clock Monitor Silent      4
# 4                          Pro Toaster Oven      5
# ..                                      ...    ...
# 995  Silent Router Phone Portable Automatic    996
# 996              Digital Treadmill Clean Go    997
# 997                  Wireless Vacuum Shaver    998
# 998  Portable Cooker Brush 360 Digital Mini    999
# 999          Smart Watch Edge Digital Sense   1000
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ...

# %%
df.isnull().sum()
# Out:
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64

# %%
 df.drop('Category', axis=1)
# Out:
#      Index                                    Name  \
# 0        1                 Thermostat Drone Heater
# 1        2   Ultra Speaker Iron Grill Advanced One
# 2        3                 Watch Headphones Kettle
# 3        4   Portable Toaster Clock Monitor Silent
# 4        5                        Pro Toaster Oven
# ..     ...                                     ...
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ...

# %%
df['Price + Stock'] = df['Price'] + df['Stock']

# %%
df.head()
# Out:
#    Index                                   Name  \
# 0      1                Thermostat Drone Heater
# 1      2  Ultra Speaker Iron Grill Advanced One
# 2      3                Watch Headphones Kettle
# 3      4  Portable Toaster Clock Monitor Silent
# 4      5                       Pro Toaster Oven
#
#                                        Description  \
# 0           Consumer approach woman us those star.
# 1  Point suggest easy money operation could white.
# 2                         Reach husband education.
# 3            Always choose school poor table main.
# 4          Worry put discuss easy back too career.
#
#                           Brand                Category  Price Currency  \
# 0                   Bradford-Yu      Kitchen Appliances     74      USD
# 1                 Douglas Group       Fitness Equipment    510      USD
# 2                 Landry-Austin  Beauty & Personal Care    254      USD
# ...

# %%
df.iloc[0, -1] = 212004

# %%
df.head()
# Out:
#    Index                                   Name  \
# 0      1                Thermostat Drone Heater
# 1      2  Ultra Speaker Iron Grill Advanced One
# 2      3                Watch Headphones Kettle
# 3      4  Portable Toaster Clock Monitor Silent
# 4      5                       Pro Toaster Oven
#
#                                        Description  \
# 0           Consumer approach woman us those star.
# 1  Point suggest easy money operation could white.
# 2                         Reach husband education.
# 3            Always choose school poor table main.
# 4          Worry put discuss easy back too career.
#
#                           Brand                Category  Price Currency  \
# 0                   Bradford-Yu      Kitchen Appliances     74      USD
# 1                 Douglas Group       Fitness Equipment    510      USD
# 2                 Landry-Austin  Beauty & Personal Care    254      USD
# ...

# %%
df.to_csv('output.csv')
